# %%
# !pip install phonenumbers
import phonenumbers
# Out:
# Collecting phonenumbers
#   Downloading phonenumbers-8.13.29-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 16.3 MB/s eta 0:00:00
# Installing collected packages: phonenumbers
# Successfully installed phonenumbers-8.13.29

# %%
#ch_number=phonenumbers.parse("phone_number","CH")
from phonenumbers import geocoder
ch_number=phonenumbers.parse("+917559337618","CH")
print(geocoder.description_for_number(ch_number,"en"))
# Out:
# India

# %%
#service_number=phonenumbers.parse("phone_number","RO")

from phonenumbers import carrier
service_number=phonenumbers.parse("+917559337618","RO")
print(carrier.name_for_number(service_number,"en"))
# Out:
# Airtel
